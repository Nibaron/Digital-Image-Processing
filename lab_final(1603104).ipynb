# %% [markdown]
# <a href="https://colab.research.google.com/github/Nibaron/Digital-Image-Processing/blob/main/lab_final(1603104).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **name: Nibaron Kumar Das**

# %% [markdown]
# **Roll:1603104**

# %% [markdown]
# Importing Libraries

# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
import numpy as np
import cv2
from cv2 import imread
from google.colab.patches import cv2_imshow
import imutils
import copy

# %% [markdown]
# upload images from Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# showing the images

# %%
imageblur = cv2.imread('/content/drive/MyDrive/DIP/person1.jpg',cv2.IMREAD_GRAYSCALE)
imagesharp = cv2.imread('/content/drive/MyDrive/DIP/person.png',cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (10,10))
plt.subplot(2,2,1)
plt.imshow(imageblur)
plt.title('Blurred Image')


plt.subplot(2,2,2)
plt.imshow(imagesharp)
plt.title('sharp Image')
# Out:
# Text(0.5, 1.0, 'sharp Image')

# %%
#Smoothing Filter

avg_image = copy.deepcopy(imageblur)
for i in range(1, imageblur.shape[0]-1):
    for j in range(1, imageblur.shape[1]-1):
        sum_image = sum([imageblur[l, k] for l in range(i-1, i+2) for k in range(j-1, j+2)])
        avg_image [i, j] = int(sum_image/9)
avg_image = copy.deepcopy(imagesharp)
for i in range(1, imagesharp.shape[0]-1):
    for j in range(1, imagesharp.shape[1]-1):
        sum_image = sum([imagesharp[l, k] for l in range(i-1, i+2) for k in range(j-1, j+2)])
        avg_image [i, j] = int(sum_image/9)


print('Gaussian Filtered Image on Blur Image')
plt.figure(figsize = (10,10))
plt.subplot(2,2,1)
plt.imshow(imageblur)
plt.subplot(2,2,2)
plt.imshow(imagesharp)
# Out:
# Gaussian Filtered Image on Blur Image

# %%
#Sharpening Filter on Image

lapla_img = copy.deepcopy(imageblur)
for i in range(1, imageblur.shape[0]-1):
    for j in range(1, imageblur.shape[1]-1):
        tmp = imageblur[i-1, j-1] + imageblur[i-1, j] + imageblur[i-1, j+1] + imageblur[i, j-1] + \
                imageblur[i, j+1] + imageblur[i+1, j-1] + imageblur[i+1, j] + imageblur[i+1, j+1] - 8*imageblur[i, j]
        lapla_img[i, j] = imageblur[i, j] - tmp
lapla_img = copy.deepcopy(imagesharp)
for i in range(1, imagesharp.shape[0]-1):
    for j in range(1, imagesharp.shape[1]-1):
        tmp = imagesharp[i-1, j-1] + imagesharp[i-1, j] + imagesharp[i-1, j+1] + imagesharp[i, j-1] + \
                imagesharp[i, j+1] + imagesharp[i+1, j-1] + imagesharp[i+1, j] + imagesharp[i+1, j+1] - 8*imagesharp[i, j]
        lapla_img[i, j] = imagesharp[i, j] - tmp

print('Sharpening Filtered Image on Image:')

plt.figure(figsize = (10,10))
plt.subplot(2,2,1)
plt.imshow(imageblur)
plt.subplot(2,2,2)
plt.imshow(imagesharp)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in ubyte_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: RuntimeWarning: overflow encountered in ubyte_scalars
#   # This is added back by InteractiveShellApp.init_path()
# Sharpening Filtered Image on Image:
